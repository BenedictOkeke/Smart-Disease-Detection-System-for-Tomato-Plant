# %% [markdown]
# <a href="https://colab.research.google.com/github/BenedictOkeke/Smart-Disease-Detection-System-for-Tomato-Plant/blob/main/Group_8_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/BenedictOkeke/Smart-Disease-Detection-System-for-Tomato-Plant.git
# Out:
# Cloning into 'Smart-Disease-Detection-System-for-Tomato-Plant'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
