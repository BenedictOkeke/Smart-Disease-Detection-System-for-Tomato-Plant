# %% [markdown]
# <a href="https://colab.research.google.com/github/BenedictOkeke/Smart-Disease-Detection-System-for-Tomato-Plant/blob/data-cleaning-team/Group_8_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/BenedictOkeke/Smart-Disease-Detection-System-for-Tomato-Plant.git
# Out:
# Cloning into 'Smart-Disease-Detection-System-for-Tomato-Plant'...
# remote: Enumerating objects: 4902, done.
# remote: Total 4902 (delta 0), reused 0 (delta 0), pack-reused 4902 (from 3)
# Receiving objects: 100% (4902/4902), 229.90 MiB | 21.09 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Updating files: 100% (5356/5356), done.

# %%
# !ls
# Out:
# sample_data  Smart-Disease-Detection-System-for-Tomato-Plant

# %%
# %cd Smart-Disease-Detection-System-for-Tomato-Plant
# Out:
# /content/Smart-Disease-Detection-System-for-Tomato-Plant

# %%
# !ls #checking the file structure
# Out:
# Dataset  Group_8_Capstone_Project.ipynb  Notebook  README.md

# %% [markdown]
# ##Mounting Google Drive to Access Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Tomato_Crop_Detection/Dataset" #confirming dataset before Authorization
# Out:
# Processed  Raw

# %% [markdown]
# ##Defining Dataset Path for Easy Accessibility
