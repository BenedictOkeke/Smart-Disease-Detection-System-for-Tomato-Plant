# %% [markdown]
# ## Cloning to Github

# %%
# !git clone https://github.com/BenedictOkeke/Smart-Disease-Detection-System-for-Tomato-Plant.git
# Out:
# fatal: destination path 'Smart-Disease-Detection-System-for-Tomato-Plant' already exists and is not an empty directory.

# %% [markdown]
# ## Mounting from Google Drive to Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os #This is used to import folders
os.listdir('/content/drive/MyDrive/Tomato_Crop_Detection') #Importing the folder for the group project
# Out:
# ['Notebook',
#  'Dataset',
#  'Python Script',
#  'Test',
#  'Requirements.txt',
#  'README.md',
#  '.gitignore']

# %%
# Let us define our dataset path so it can easily be accessible
dataset_path = "/content/drive/MyDrive/Tomato_Crop_Detection/Dataset/Raw"

# %%
# Checking to see the disease folders in the raw dataset
os.listdir(dataset_path)
# Out:
# ['Tomato septoria leaf spot',
#  'Tomato leaf blight',
#  'Tomato leaf curl',
#  'Tomato verticulium wilt',
#  'Tomato healthy']

# %%
# Let us see how many images are contained in each diseased and healthy folder using len(), the function that tells us how many items are in a variable
for folder in os.listdir(dataset_path):
  folder_path = os.path.join(dataset_path, folder)
  print(folder, len(os.listdir(folder_path)))
# Out:
# Tomato septoria leaf spot 2759
# Tomato leaf blight 1315
# Tomato leaf curl 518
# Tomato verticulium wilt 759
# Tomato healthy 470

# %% [markdown]
# ## Data Cleaning
